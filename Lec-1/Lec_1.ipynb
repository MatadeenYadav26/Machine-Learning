# %% [markdown]
# # Python Lec-1
# ## Learning '#' and '##'

# %% [markdown]
# -DataTypes

# %% [markdown]
# - Short cut to create a cell : esc + a

# %%
1+1
# Out:
# 2

# %%
    10*'str'
# Out:
# 'strstrstrstrstrstrstrstrstrstr'

# %%
type('aman')
# Out:
# str

# %%
print("Hello World")
# Out:
# Hello World

# %%
firstname = "Aman"
secondname = "Yadav"

# %%
print("My first name is {} and last name is {}".format(firstname,secondname))
# Out:
# My first name is Aman and last name is Yadav

# %%
# 2nd method :
print(f"firstname = {firstname}.")
# Out:
# firstname = Aman.

# %%
len("aman")
# Out:
# 4

# %%
type(['1','2'])
# Out:
# list
